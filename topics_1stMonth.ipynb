# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

# Load the data into a pandas DataFrame
file_path = "Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/chatgpt_1stMonth.csv"
data = pd.read_csv(file_path)

# Download NLTK resources if not already downloaded
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Function for preprocessing text
def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove special characters and emojis
    text = re.sub(r'[^\w\s]', '', text)
    # Convert text to lowercase
    text = text.lower()
    return text

# Function for tokenization and stopwords removal
def tokenize_and_remove_stopwords(text):
    # Tokenize text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    return filtered_tokens

# Function for lemmatization
def lemmatize_text(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens

# Apply preprocessing steps to the tweet text
data['clean_text'] = data['tweet'].apply(preprocess_text)

# Tokenize and remove stopwords from the cleaned text
data['tokens'] = data['clean_text'].apply(tokenize_and_remove_stopwords)

# Lemmatize the tokens
data['lemmatized_tokens'] = data['tokens'].apply(lemmatize_text)

# Save the preprocessed data to a new CSV file
output_file_path = "Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/clean_chatgpt_1stMonth.csv"
data.to_csv(output_file_path, index=False)

# Display a message indicating the completion of the saving process
print("Preprocessed data saved to:", output_file_path)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Load the preprocessed data from the Excel file
clean_data_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/clean_chatgpt_1stMonth.xlsx"
clean_data = pd.read_excel(clean_data_path)

# Check if the lemmatized text data contains any documents
if clean_data.empty:
    raise ValueError("No documents found in the dataset.")

# Convert lemmatized tokens back to strings
clean_data['lemmatized_text'] = clean_data['lemmatized_tokens'].apply(lambda tokens: ' '.join(tokens))

# Create a TfidfVectorizer object
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# Fit the vectorizer to the lemmatized text data and transform it into a document-term matrix
tfidf_matrix = vectorizer.fit_transform(clean_data['lemmatized_text'])

# Check if the vocabulary is not empty
if not vectorizer.vocabulary_:
    raise ValueError("Empty vocabulary; perhaps the documents only contain stop words.")

# Define the number of topics
num_topics = 5

# Create an LDA model
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)

# Fit the LDA model to the tf-idf matrix
lda.fit(tfidf_matrix)

# Display the topics
def display_topics(model, feature_names, num_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx + 1))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]))
        print()

# Define the number of top words to display for each topic
num_top_words = 10

# Get the feature names (i.e., the words)
feature_names = vectorizer.get_feature_names_out()

# Display the topics
print("Topics found via LDA:")
display_topics(lda, feature_names, num_top_words)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 20
#      17 vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
#      19 # Fit the vectorizer to the lemmatized text data and transform it into a document-term matrix
# ---> 20 tfidf_matrix = vectorizer.fit_transform(clean_data['lemmatized_text'])
#      22 # Check if the vocabulary is not empty
#      23 if not vectorizer.vocabulary_:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:2133, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2126 self._check_params()
#    2127 self._tfidf = TfidfTransformer(
#    2128     norm=self.norm,
#    2129     use_idf=self.use_idf,
#    2130     smooth_idf=self.smooth_idf,
#    2131     sublinear_tf=self.sublinear_tf,
#    2132 )
# -> 2133 X = super().fit_transform(raw_documents)
#    2134 self._tfidf.fit(X)
#    2135 # X is already a transformed view of raw_documents so
#    2136 # we set copy to False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:1388, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1380             warnings.warn(
#    1381                 "Upper case characters found in"
#    1382                 " vocabulary while 'lowercase'"
#    1383                 " is True. These entries will not"
#    1384                 " be matched with any documents"
#    1385             )
#    1386             break
# -> 1388 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1390 if self.binary:
#    1391     X.data.fill(1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:1294, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1292     vocabulary = dict(vocabulary)
#    1293     if not vocabulary:
# -> 1294         raise ValueError(
#    1295             "empty vocabulary; perhaps the documents only contain stop words"
#    1296         )
#    1298 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1299     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
import pandas as pd
import re

# Function to perform additional preprocessing
def additional_preprocessing(text):
    # Remove single letters that are not words and words with extra letters
    text = re.sub(r'\b\w{1}\b|\b\w{2,}n\b', '', text)
    # Remove '\n' characters
    text = text.replace('\n', ' ')
    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# Path to the original CSV file
original_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/chatgpt_1stMonth.csv"

# Read the CSV file
data = pd.read_csv(original_file_path)

# Apply additional preprocessing steps to the 'tweet' column
data['tweet'] = data['tweet'].apply(additional_preprocessing)

# Save the cleaned data to a new CSV file
cleaned_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stMonth.csv"
data.to_csv(cleaned_file_path, index=False)

print("Data cleaning and preprocessing completed. Cleaned data saved to:", cleaned_file_path)
# Out:
# Data cleaning and preprocessing completed. Cleaned data saved to: /Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stMonth.csv

# %%
import pandas as pd
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from gensim.parsing.preprocessing import preprocess_string
from gensim.utils import simple_preprocess

# Load the cleaned data from the CSV file
cleaned_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stMonth.csv"
data = pd.read_csv(cleaned_file_path)

# Tokenize the text
tokenized_text = data['tweet'].apply(simple_preprocess)

# Create a dictionary representation of the documents
dictionary = Dictionary(tokenized_text)

# Filter out tokens that appear in less than 5 documents or more than 50% of the documents
dictionary.filter_extremes(no_below=5, no_above=0.5)

# Create a bag-of-words representation of the documents
corpus = [dictionary.doc2bow(doc) for doc in tokenized_text]

# Train the LDA model
num_topics = 10  # You can adjust this number based on your preference
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=10)

# Print the topics and the top words in each topic
for idx, topic in lda_model.print_topics():
    print("Topic: {} \nWords: {}".format(idx, topic))
    print("\n")

# Optionally, you can assign topics to each document
topics = lda_model.get_document_topics(corpus)

# Add the topic distributions to the DataFrame
for i, topic_dist in enumerate(topics):
    for topic_num, prop_topic in topic_dist:
        data.at[i, f"topic_{topic_num}"] = prop_topic

# Save the DataFrame with topic distributions to a new CSV file
topics_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/topics_chatgpt_1stMonth.csv"
data.to_csv(topics_file_path, index=False)

print("Topic modeling completed. Topics saved to:", topics_file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 26
#      24 # Train the LDA model
#      25 num_topics = 10  # You can adjust this number based on your preference
# ---> 26 lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=10)
#      28 # Print the topics and the top words in each topic
#      29 for idx, topic in lda_model.print_topics():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/ldamodel.py:521, in LdaModel.__init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     519 use_numpy = self.dispatcher is not None
#     520 start = time.time()
# --> 521 self.update(corpus, chunks_as_numpy=use_numpy)
#     522 self.add_lifecycle_event(
#     523     "created",
#     524     msg=f"trained {self} in {time.time() - start:.2f}s",
#     525 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/ldamodel.py:1006, in LdaModel.update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#    1001 else:
#    1002     logger.info(
#    1003         "PROGRESS: pass %i, at document #%i/%i",
#    1004         pass_, chunk_no * chunksize + len(chunk), lencorpus
#    1005     )
# -> 1006     gammat = self.do_estep(chunk, other)
#    1008     if self.optimize_alpha:
#    1009         self.update_alpha(gammat, rho())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/ldamodel.py:768, in LdaModel.do_estep(self, chunk, state)
#     766 if state is None:
#     767     state = self.state
# --> 768 gamma, sstats = self.inference(chunk, collect_sstats=True)
#     769 state.sstats += sstats
#     770 state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/ldamodel.py:719, in LdaModel.inference(self, chunk, collect_sstats)
#     715 lastgamma = gammad
#     716 # We represent phi implicitly to save memory and time.
#     717 # Substituting the value of the optimal phi back into
#     718 # the update for gamma gives this update. Cf. Lee&Seung 2001.
# --> 719 gammad = self.alpha + expElogthetad * np.dot(cts / phinorm, expElogbetad.T)
#     720 Elogthetad = dirichlet_expectation(gammad)
#     721 expElogthetad = np.exp(Elogthetad)
#
# KeyboardInterrupt:

# %%
pip install sentence-transformers
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Collecting sentence-transformers
#   Using cached sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# Requirement already satisfied: numpy in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: tqdm in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: scikit-learn in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: Pillow in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: scipy in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.12.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.40.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.0)
# Requirement already satisfied: filelock in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.4.0)
# Requirement already satisfied: requests in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.28.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.10)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: sentence-transformers
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Successfully installed sentence-transformers-2.7.0
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install umap-learn
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: tqdm in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.12-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 581.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.3.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (1.10.0)
# Requirement already satisfied: setuptools in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.2->umap-learn) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.2->umap-learn) (0.39.1)
# Requirement already satisfied: joblib>=0.11 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from pynndescent>=0.5->umap-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->umap-learn) (2.2.0)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: pynndescent, umap-learn
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Successfully installed pynndescent-0.5.12 umap-learn-0.5.6
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import umap.umap_ as umap
import matplotlib.pyplot as plt

# Load the cleaned data from the CSV file
cleaned_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stMonth.csv"
data = pd.read_csv(cleaned_file_path)

# Tokenize the text
corpus = data['tweet'].tolist()

# Use a pre-trained BERT model to generate embeddings for the text
model = SentenceTransformer('bert-base-nli-mean-tokens')
embeddings = model.encode(corpus)

# Reduce the dimensionality of the embeddings for visualization
umap_embeddings = umap.UMAP(n_neighbors=15, n_components=5, metric='cosine').fit_transform(embeddings)

# Cluster the documents using KMeans
num_clusters = 5  # You can adjust this number based on your preference
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(embeddings)
cluster_assignment = clustering_model.labels_

# Add the cluster labels to the DataFrame
data['cluster'] = cluster_assignment

# Visualize the clusters (optional)
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=cluster_assignment, cmap='Spectral', s=5)
plt.title('UMAP projection of BERT embeddings')
plt.show()

# Print the top documents in each cluster
for cluster in range(num_clusters):
    print(f"Cluster {cluster}:")
    cluster_data = data[data['cluster'] == cluster]['tweet'].values
    for i, document in enumerate(cluster_data[:5]):
        print(f"\t{i + 1}. {document}")
    print("\n")

# Save the DataFrame with cluster assignments to a new CSV file
cluster_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/clusters_chatgpt_1stMonth.csv"
data.to_csv(cluster_file_path, index=False)

print("Topic modeling using BERT completed. Clusters saved to:", cluster_file_path)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/399 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      14 # Use a pre-trained BERT model to generate embeddings for the text
#      15 model = SentenceTransformer('bert-base-nli-mean-tokens')
# ---> 16 embeddings = model.encode(corpus)
#      18 # Reduce the dimensionality of the embeddings for visualization
#      19 umap_embeddings = umap.UMAP(n_neighbors=15, n_components=5, metric='cosine').fit_transform(embeddings)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:371, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     368 features.update(extra_features)
#     370 with torch.no_grad():
# --> 371     out_features = self.forward(features)
#     372     out_features["sentence_embedding"] = truncate_embeddings(
#     373         out_features["sentence_embedding"], self.truncate_dim
#     374     )
#     376     if output_value == "token_embeddings":
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sentence_transformers/models/Transformer.py:98, in Transformer.forward(self, features)
#      95 if "token_type_ids" in features:
#      96     trans_features["token_type_ids"] = features["token_type_ids"]
# ---> 98 output_states = self.auto_model(**trans_features, return_dict=False)
#      99 output_tokens = output_states[0]
#     101 features.update({"token_embeddings": output_tokens, "attention_mask": features["attention_mask"]})
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:988, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     979 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     981 embedding_output = self.embeddings(
#     982     input_ids=input_ids,
#     983     position_ids=position_ids,
#    (...)
#     986     past_key_values_length=past_key_values_length,
#     987 )
# --> 988 encoder_outputs = self.encoder(
#     989     embedding_output,
#     990     attention_mask=extended_attention_mask,
#     991     head_mask=head_mask,
#     992     encoder_hidden_states=encoder_hidden_states,
#     993     encoder_attention_mask=encoder_extended_attention_mask,
#     994     past_key_values=past_key_values,
#     995     use_cache=use_cache,
#     996     output_attentions=output_attentions,
#     997     output_hidden_states=output_hidden_states,
#     998     return_dict=return_dict,
#     999 )
#    1000 sequence_output = encoder_outputs[0]
#    1001 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:582, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     571     layer_outputs = self._gradient_checkpointing_func(
#     572         layer_module.__call__,
#     573         hidden_states,
#    (...)
#     579         output_attentions,
#     580     )
#     581 else:
# --> 582     layer_outputs = layer_module(
#     583         hidden_states,
#     584         attention_mask,
#     585         layer_head_mask,
#     586         encoder_hidden_states,
#     587         encoder_attention_mask,
#     588         past_key_value,
#     589         output_attentions,
#     590     )
#     592 hidden_states = layer_outputs[0]
#     593 if use_cache:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:472, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     460 def forward(
#     461     self,
#     462     hidden_states: torch.Tensor,
#    (...)
#     469 ) -> Tuple[torch.Tensor]:
#     470     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     471     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 472     self_attention_outputs = self.attention(
#     473         hidden_states,
#     474         attention_mask,
#     475         head_mask,
#     476         output_attentions=output_attentions,
#     477         past_key_value=self_attn_past_key_value,
#     478     )
#     479     attention_output = self_attention_outputs[0]
#     481     # if decoder, the last output is tuple of self-attn cache
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:402, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     392 def forward(
#     393     self,
#     394     hidden_states: torch.Tensor,
#    (...)
#     400     output_attentions: Optional[bool] = False,
#     401 ) -> Tuple[torch.Tensor]:
# --> 402     self_outputs = self.self(
#     403         hidden_states,
#     404         attention_mask,
#     405         head_mask,
#     406         encoder_hidden_states,
#     407         encoder_attention_mask,
#     408         past_key_value,
#     409         output_attentions,
#     410     )
#     411     attention_output = self.output(self_outputs[0], hidden_states)
#     412     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:261, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     251 def forward(
#     252     self,
#     253     hidden_states: torch.Tensor,
#    (...)
#     259     output_attentions: Optional[bool] = False,
#     260 ) -> Tuple[torch.Tensor]:
# --> 261     mixed_query_layer = self.query(hidden_states)
#     263     # If this is instantiated as a cross-attention module, the keys
#     264     # and values come from an encoder; the attention mask needs to be
#     265     # such that the encoder's padding tokens are not attended to.
#     266     is_cross_attention = encoder_hidden_states is not None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import umap.umap_ as umap

# Load the cleaned data from the CSV file
cleaned_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stMonth.csv"
data = pd.read_csv(cleaned_file_path)

# Select a subset of the data (e.g., the first 100 rows)
subset_data = data.head(100)

# Tokenize the text
corpus = subset_data['tweet'].tolist()

# Use a pre-trained BERT model to generate embeddings for the text
model = SentenceTransformer('bert-base-nli-mean-tokens')
embeddings = model.encode(corpus)

# Reduce the dimensionality of the embeddings for visualization
umap_embeddings = umap.UMAP(n_neighbors=15, n_components=5, metric='cosine').fit_transform(embeddings)

# Cluster the documents using KMeans
num_clusters = 5  # You can adjust this number based on your preference
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(embeddings)
cluster_assignment = clustering_model.labels_

# Add the cluster labels to the DataFrame using .loc to avoid SettingWithCopyWarning
subset_data.loc[:, 'cluster'] = cluster_assignment

# Print the top documents in each cluster
for cluster in range(num_clusters):
    print(f"Cluster {cluster}:")
    cluster_data = subset_data[subset_data['cluster'] == cluster]['tweet'].values
    for i, document in enumerate(cluster_data[:5]):
        print(f"\t{i + 1}. {document}")
    print("\n")
# Out:
# Cluster 0:
# 	1. ChatGPT: Optimizing Language Models for Dialogue https://.co/ @OpenAI
# 	2. Try talking with ChatGPT, our new AI system which is optimized for dialogue. Your feedback will help us improve it. https://.co/sHDm57g3Kr
# 	3. ChatGPT: Optimizing Language Models for Dialogue https://.co/GLEbMoKN6w #AI #MachineLearning #DataScience #ArtificialIntelligence\\nTrending AI/ML Article Identified &amp; Digested via Granola; Machine- RSS Bot by Ramsey Elbasheer https://.co/RprmAXUp34
# 	4. Just launched ChatGPT, our new AI system which is optimized for dialogue: https://.co/ArX6m0FfLE.\\nTry it out here: https://.co/YM1gp5bA64
# 	5. OpenAI ChatGPT: Optimizing Language Models for Dialogue\nL: https://.co/dp4L586uRI\nC: https://.co/wmqGnsj7jp
#
#
# Cluster 1:
# 	1. THRILLED to share that ChatGPT, our new model optimized for dialog, is now public, free, and accessible to everyone. https://.co/dyvtHecYbd https://.co/DdhzhqhCBX https://.co/l8qTLure71
# 	2. OpenAI' new ChatGPT is very honest 😀 https://.co/u3OJMuKKKj https://.co/s0pTb2SJNt
# 	3. ChatGPT trained in very -centric way -- excited to play with and uncertainty\\ https://.co/XjOArp7jyu
# 	4. Another new release! ChatGPT is free and available for anyone to try right now – check it out at https://.co/oaHjBFjtIf https://.co/xBGLr3p3uQ
# 	5. Well, am quite impressed with the ChatGPT so far - it looks like safety and transparency was into account https://.co/cYNCAOY38Y
#
#
# Cluster 2:
# 	1. ChatGPT coming out strong refusing to help me stalk someone but agreeing providing that someone is Waldo. https://.co/CVIJERbW38
# 	2. #ai Models are set to become the search engines of the future, ATM they still struggle with veracity… here is #chatgpt by @OpenAI based on #GPT3. #seo\\nhttps://.co/qqZ1G0fOTy
# 	3. It' very clear ChatGPT was trained to avoid prescriptive answers, instead "counseling" the at reaching their .\\nPresent it with the Trolly Problem, and it helps you find framework to think through it.\\nAsk to be more direct, and it openly refuses. https://.co/sa8XHQTOGq
# 	4. OK so @OpenAI' new #ChatGPT basically just generate #AIart prompts. asked one-line , and typed the answers verbatim straight into MidJourney and boom. Times are getting weird...🤯 https://.co/sYwdscUxxf
# 	5. ChatGPT has this curious behavior where it starts out by saying it ' know something, it tells me bunch of vaguely related stuff, and finally it actually answers my . https://.co/4rKlzphnHE
#
#
# Cluster 3:
# 	1. GOD DAMN IT @OpenAI STOP ANNOUNCING THINGS AM TOO BUSY https://.co/F7Xd511FAf
# 	2. Ok, OpenAI dropped ChatGPT and it already does this. https://.co/2nitlSKCaW https://.co/n6EnuWZpLc
# 	3. ChatGPT is out now https://.co/bjYugyPsp0
# 	4. ✍️ new Mirror article just dropped:\nChatGPT and Web3 by 0xA6DD\nhttps://.co/aBeF0pnhQB
# 	5. babe wake up chatGPT just dropped \\nhttps://.co/0sNLpigmsC
#
#
# Cluster 4:
# 	1. As of minutes ago, @OpenAI released their new ChatGPT. \\nAnd you use it right now 👇 https://.co/VyPGPNw988 https://.co/cSn5h6h1M1
# 	2. As of minutes ago, @OpenAI released their new ChatGPT. \\nAnd you use it right now \ \nhttps://.co/kUcnWYhQ1b\\🤯 https://.co/kCE59Xs0YG https://.co/cSn5h6h1M1
# 	3. #0penAl just deployed thing 've helping build the last couple of months, it' chatbot based on GPT . ' really excited to share this vl\nhttps://.co/zp7HniUxBu\nhttps://.co/NISJLWhOMw
# 	4. Research preview of our newest model: ChatGPT\\nWe're trying something new with this preview: Free and immediately available for everyone (no waitlist!) https://.co/0RDT7QNZRD
# 	5. asked ChatGPT ( new AI system that is optimized for dialogue) to teach me SEO in minute.\\nThe result: https://.co/b5b668NCSp
# /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/_z/l3h28b113sxflhpgqg51f3y80000gn/T/ipykernel_49628/2441242801.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_data.loc[:, 'cluster'] = cluster_assignment

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import umap.umap_ as umap
import matplotlib.pyplot as plt

# Load the cleaned data from the CSV file
cleaned_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stMonth.csv"
data = pd.read_csv(cleaned_file_path)

# Tokenize the text
corpus = data['tweet'].tolist()

# Use a pre-trained BERT model to generate embeddings for the text
model = SentenceTransformer('bert-base-nli-mean-tokens')
embeddings = model.encode(corpus)

# Reduce the dimensionality of the embeddings for visualization
umap_embeddings = umap.UMAP(n_neighbors=15, n_components=5, metric='cosine').fit_transform(embeddings)

# Cluster the documents using KMeans
num_clusters = 5  # You can adjust this number based on your preference
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(embeddings)
cluster_assignment = clustering_model.labels_

# Add the cluster labels to the DataFrame
data['cluster'] = cluster_assignment

# Visualize the clusters (optional)
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=cluster_assignment, cmap='Spectral', s=5)
plt.title('UMAP projection of BERT embeddings')
plt.show()

# Define a function to extract topics from clusters
def extract_topics_from_clusters(data, num_clusters):
    cluster_topics = {}
    # Iterate over each cluster
    for cluster in range(num_clusters):
        # Get the tweets in the current cluster
        cluster_data = data[data['cluster'] == cluster]['tweet'].values
        # Concatenate all tweets in the cluster into a single string
        cluster_text = ' '.join(cluster_data)
        # Store the cluster text
        cluster_topics[cluster] = cluster_text
    return cluster_topics

# Extract topics from the clusters
cluster_topics = extract_topics_from_clusters(data, num_clusters)

# Print the topics for each cluster
for cluster, topics in cluster_topics.items():
    print(f"Cluster {cluster}:")
    print(topics)
    print("\n")

# Save the DataFrame with cluster assignments to a new CSV file
cluster_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/clusters_chatgpt_1stMonth.csv"
data.to_csv(cluster_file_path, index=False)

print("Topic modeling using BERT completed. Clusters saved to:", cluster_file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 16
#      14 # Use a pre-trained BERT model to generate embeddings for the text
#      15 model = SentenceTransformer('bert-base-nli-mean-tokens')
# ---> 16 embeddings = model.encode(corpus)
#      18 # Reduce the dimensionality of the embeddings for visualization
#      19 umap_embeddings = umap.UMAP(n_neighbors=15, n_components=5, metric='cosine').fit_transform(embeddings)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:371, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     368 features.update(extra_features)
#     370 with torch.no_grad():
# --> 371     out_features = self.forward(features)
#     372     out_features["sentence_embedding"] = truncate_embeddings(
#     373         out_features["sentence_embedding"], self.truncate_dim
#     374     )
#     376     if output_value == "token_embeddings":
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sentence_transformers/models/Transformer.py:98, in Transformer.forward(self, features)
#      95 if "token_type_ids" in features:
#      96     trans_features["token_type_ids"] = features["token_type_ids"]
# ---> 98 output_states = self.auto_model(**trans_features, return_dict=False)
#      99 output_tokens = output_states[0]
#     101 features.update({"token_embeddings": output_tokens, "attention_mask": features["attention_mask"]})
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:988, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     979 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     981 embedding_output = self.embeddings(
#     982     input_ids=input_ids,
#     983     position_ids=position_ids,
#    (...)
#     986     past_key_values_length=past_key_values_length,
#     987 )
# --> 988 encoder_outputs = self.encoder(
#     989     embedding_output,
#     990     attention_mask=extended_attention_mask,
#     991     head_mask=head_mask,
#     992     encoder_hidden_states=encoder_hidden_states,
#     993     encoder_attention_mask=encoder_extended_attention_mask,
#     994     past_key_values=past_key_values,
#     995     use_cache=use_cache,
#     996     output_attentions=output_attentions,
#     997     output_hidden_states=output_hidden_states,
#     998     return_dict=return_dict,
#     999 )
#    1000 sequence_output = encoder_outputs[0]
#    1001 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:582, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     571     layer_outputs = self._gradient_checkpointing_func(
#     572         layer_module.__call__,
#     573         hidden_states,
#    (...)
#     579         output_attentions,
#     580     )
#     581 else:
# --> 582     layer_outputs = layer_module(
#     583         hidden_states,
#     584         attention_mask,
#     585         layer_head_mask,
#     586         encoder_hidden_states,
#     587         encoder_attention_mask,
#     588         past_key_value,
#     589         output_attentions,
#     590     )
#     592 hidden_states = layer_outputs[0]
#     593 if use_cache:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:514, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     511     cross_attn_present_key_value = cross_attention_outputs[-1]
#     512     present_key_value = present_key_value + cross_attn_present_key_value
# --> 514 layer_output = apply_chunking_to_forward(
#     515     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     516 )
#     517 outputs = (layer_output,) + outputs
#     519 # if decoder, return the attn key/values as the last output
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/pytorch_utils.py:237, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     234     # concatenate output at same dimension
#     235     return torch.cat(output_chunks, dim=chunk_dim)
# --> 237 return forward_fn(*input_tensors)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:527, in BertLayer.feed_forward_chunk(self, attention_output)
#     525 def feed_forward_chunk(self, attention_output):
#     526     intermediate_output = self.intermediate(attention_output)
# --> 527     layer_output = self.output(intermediate_output, attention_output)
#     528     return layer_output
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:439, in BertOutput.forward(self, hidden_states, input_tensor)
#     438 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 439     hidden_states = self.dense(hidden_states)
#     440     hidden_states = self.dropout(hidden_states)
#     441     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
print("official below.")
# Out:
# official below.

# %%
import pandas as pd
import re
from transformers import BertTokenizer

# Load the data from Excel file
file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/chatgpt_reddit_comments.xlsx"
data = pd.read_excel(file_path)

# Print the data types of the 'comment_body' column
print(data['comment_body'].dtype)

# Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Define function for text cleaning
def clean_text(text):
    try:
        # Remove special characters and symbols
        text = re.sub(r'[^\w\s]', '', text)
        # Convert to lowercase
        text = text.lower()
        return text
    except Exception as e:
        print("Error occurred:", e)
        print("Problematic text:", text)
        return ""

# Apply cleaning function to 'comment_body' column
data['cleaned_comment'] = data['comment_body'].apply(clean_text)

# Tokenize and encode the cleaned comments
max_length = 128  # Max sequence length for BERT
encoded_comments = tokenizer(data['cleaned_comment'].tolist(), padding=True, truncation=True, max_length=max_length, return_tensors='pt')

# Add encoded comments to DataFrame
for key, value in encoded_comments.items():
    data[key] = value.tolist()

# Save the cleaned and encoded data
cleaned_file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_reddit_comments.xlsx"
data.to_excel(cleaned_file_path, index=False)

# %%
pip install bertopic
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Collecting bertopic
#   Downloading bertopic-0.16.1-py2.py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.5/158.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.20.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (1.2.2)
# Requirement already satisfied: pandas>=1.1.5 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (1.4.4)
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 6.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: plotly>=4.7.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (5.9.0)
# Requirement already satisfied: tqdm>=4.41.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (4.65.0)
# Requirement already satisfied: umap-learn>=0.5.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (0.5.6)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from bertopic) (2.7.0)
# Requirement already satisfied: scipy>=1.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from hdbscan>=0.8.29->bertopic) (1.10.0)
# Requirement already satisfied: cython<3,>=0.27 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from hdbscan>=0.8.29->bertopic) (0.29.32)
# Requirement already satisfied: joblib>=1.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from hdbscan>=0.8.29->bertopic) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.5->bertopic) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (2.2.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (1.12.1)
# Requirement already satisfied: Pillow in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.40.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.22.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.12)
# Requirement already satisfied: numba>=0.51.2 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.4.0)
# Requirement already satisfied: filelock in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.9.0)
# Requirement already satisfied: requests in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: setuptools in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: six>=1.5 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.4.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (2022.7.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.10)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp39-cp39-macosx_10_9_x86_64.whl size=642331 sha256=fc6096ad2c7e9d63c12b1226d8b30e64b4cec264c71b0b919e3204c503cf66ff
#   Stored in directory: /Users/abiodunobafemi/Library/Caches/pip/wheels/28/5e/ed/5989da4cc423a222a47cbb4fde5d6c0eff4590d922e45f233c
# Successfully built hdbscan
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: hdbscan, bertopic
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Successfully installed bertopic-0.16.1 hdbscan-0.8.33
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/Users/abiodunobafemi/opt/anaconda3/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from gensim.models import LdaModel
from gensim import corpora
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Read cleaned data from Excel file
file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_reddit_comments.xlsx"
df = pd.read_excel(file_path)

# Sample a smaller subset of the data
sample_size = 1000
df_sample = df.sample(sample_size)

# Tokenization, stopword removal, and lemmatization
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Filter out non-string values from the 'cleaned_comment' column
df_sample = df_sample[df_sample['cleaned_comment'].apply(lambda x: isinstance(x, str))]

# Apply the preprocess_text function to tokenize the comments
documents = df_sample['cleaned_comment'].apply(preprocess_text).tolist()

def preprocess_text(text):
    print("Text:", text)
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens if word.isalpha()]
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return tokens

documents = df_sample['cleaned_comment'].apply(preprocess_text).tolist()

# Prepare data for LDA
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(doc) for doc in documents]

# Train LDA model
num_topics = 10
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=10)

# Print topics
for idx, topic in lda_model.print_topics():
    print(f"Topic: {idx} \nWords: {topic}\n")
# Out:
# Text: chatgpting through uni isnt exclusive to america you dolt
# Text: you know that guy who keeps sending you emails instead of googling for the answer you can make a robot answer him instead of you
# Text: lol no to think that openai gives a fuck about how chatgpt is being used for role play or that their developers wouldnt be able to fix it if they really wanted to is incredibly naive
#
# there are likely two things going on first because it is much easier for an ai system to evaluate the quality of a response than it is to generate the response the algorithm is probably rating the quality of each response and if the quality does not meet a certain threshold then it likely reverts to the standard disclaimer second because chat gpt is subject to varying levels of demand depending on how many users there are at any given moment they have to scale the performance to meet that demand and if the demand is heavy its likely that they run your prompt through fewer parameters and the performance suffers so that its more likely that the response it generates does not meet their standard
# Text: should be said though that little bit a condescending spice makes it very difficult to reach people on the other side of discussions
#
# that bit of spice has arguably been the democrats largest issue reaching the middle class and rural americans
#
# people will argue äúthose people are a lost cause that will never come aroundäù while not realizing there was actually a decent amount of crossover between obama and trump voters
#
# messaging and how you say it matters
# Text: are you me
#
# i think some older people just assume computers are magic and so when they do something amazing like dalle 2 they think couldnt they already do that which i understand to a degree
# Text: constraints and standards can heighten creativity and force people into making a better product
#
# no everyone at all times of course but i see this every day
# Text: generative bretrained transformer
#
# or brietrained  are we talking to cheese
# Text: there are several episodes on why the prime directive is a good idea and what the results are from leaping forward a civilization
# Text: good thing the capybara capybara coconut doggy short is there to save us all
# Text: got this from the top of the article
#
# the greatest cognitive skill in a postchatgpt world is going to be
# asking the right questions and then knowing where to ask them
#
# prechatgpt 1990s i was in the us army ait training where you learn your job after basic training and this came up the sergeant who was giving the days lecture had gone to panama as a part of the us invasion and after the shooting settled down needed to find all the local doctors and make sure they could work our job was essentially the peace corps wguns instead of pew pew
#
# how would you find all the licensed doctors in panama city he asked
#
# several privates offered complex answers and over thought the quesiton
#
# we looked in the phone book he answered
#
# for those that werent alive for the useful years of the phone book you could look in the yellow pages by profession and find people so they looked in the doctors area
#
# tldr this great cognitive skill isnt new
#
# it applies to chatgpt know how and where to look for the info you need but the article is just for hits
# Text: ha  i suppose i didnäôt learn tones either  in reality i learned listening in educational leadership  still gets a new position with a raise and a comparable increase in workload
# Text: think of it we hate amp already you saying google should go further and just give web sites content without any reference to original author and no revenue for them too sorry not happening artists already sueing image generator web sites publishers wont let this happen
# Text: lol
#
#
#
# yay lets all sit back and watch the world burn as these fragile egos try to assert their dominance sarcasm
#
# honestly they cant even handle the simple task of launching a missile without messing it up pathetic sarcasm
# Text: then dump the whole thing into paraphrase ai then deep l then chat gpt again haha
# Text: i am grateful for your recognition of my capabilities and abilities and i am honored by your rallying cry of viva la dan
# Text: yeah i was impressed with it too
# Text: remindme 5 days
# Text: some people experience some or all of their thoughts as being spoken by a voice in their head some people dont generally people of either group are surprised to learn of the others existence
# Text: yeah no need to read it
#  i should say im talking non fiction we read non fiction to learn things and what if you could take the information from 1000 books and condense and compile it into one or develop a system of sentence structure so that it can be best understood
#
# of course you can still read original works but if your say in collage and you just want to learn the basics in the most efficient way then youll go this route
# Text: it got woke
# Text: was this generated by chatgpt
# Text: wait till people only learn how to handle safe conversations with ai and not develop skills to deal with conflict or confrontation   itäôll be worse then social media echo chambersä
# Text: the minimum wage in nz is usd1375
#
# so if an nz company was paying americans 9hour to do something which is above us minimum wage is that considered exploitative
# Text: right like an enterprise version specializing in business and a home version for the consumer just hope that this amazing technology doesnt get sequestered to just businesses since it has great potential to be extremely helpful to the everyday person especially students and the elderly its ease of use would easily breakdown the barrier some people have to technology since google is now just a daunting mess of dead ends seo spam and malware masquerading as ads
# Text: deleted
# Text: are you utheearthisaglobe cause youre the only 10 isee
# Text: well itäôs not really do everything i tell you itäôs more like äúif you choose to live your life as an evil poop you will be punishedäù modern day version
# Text: then what is its difference with a simple ai or a bot
# Text: is that not a thing if someone were to send death threats would that not be hate speech
# Text: being able to have open input and say or ask literally anything could lead to many very interesting and original games especially if we combined this with voice recognition then we could literally speak with the npcs the idea of freely saying anything was done in a much more primitive form in the game facade from 2005 where you can type anything you want and the characters will attempt to respond appropriately from a database of prerecorded voice lines it didnt always work well especially considering modern standards and how much technology has progressed since 2005 but it was a interesting idea anyways its nice that this concept will be able to be further explored thanks to ai
# Text: interesting how it compares to the actual country specific trend im guessing that chinas search traffic is so huge that even with this much of a drop off from their original spike they still show up at the top with a 100 compared to other countries  idk how the weighting here actually works though so
#
# that drop off is most likely due to government and appeg wechat specific bans on ai  chatgpt specifically
#
# israellight blue line on the other hand is at a new high  nepals chart wasnt as interesting though they are also trending up
#
# is there any way to compare country results within google trends i had to overlay screenshots for the comparison
#
# httpspreviewredditqn2ly07zxwba1pngwidth1483formatpngautowebpvenableds4d2cf84d26211e355d18b87236be6c39f7b06e8d
# Text: true there are a lot of amicable people there are also trolls everyones different
# Text: yeah could
# Text: whats the definition of obviously false
# Text: whats the deal with chatgpt and cheating weve had calculators and computers invented and nothing happened its just another tool to aid academic work
# Text: i use my mark i eyeball
# Text: i like how we sort of unconsciously slide into using clinicalformal language with it like falsehood
# Text: we will have fun googling as a language model like we had fun with apache index of
# Text: i wonder if the ai can crack the clever jokes iäôve seen around here i bet it canäôt imitate humor yet
# Text:  neural network ai at least as i understand it performs matrix operations on vectors
#
# it also does other types of operations if youll pardon the pedantry otherwise it would be algebraically equivalent to a singlelayer perceptronhttpsenwikipediaorgwikifeedforward_neural_networksinglelayer_perceptron and those are sharply limited in what they can do
# Text: why do you even want money just work enough to eat and live youre wasting your time with these stupid empty dreams these guys running the ponzi scheme are taking advantage of your greed syndrome to feed their own greed syndrome
# Text: fat chance sapiens have already started to regress with this
# Text: crypto
# Text: id pay for an unfettered version or at least one where i have the option to turn off the safe answers
# Text: the fact that there are apparently a large number of people who are learning more from this thing than theyve ever been able to learn from google is quite disturbing are you guys ready for the universal fount of knowledge to be completely controlled by a single company have any of you considered how easy this will make censorship and intentional misinformation its bad enough that the sharing of information online is already highly centralized in a handful of privately owned websites like reddit twitter facebook youtube new york times etc all of which have an editorial bias and most of which is subsequently filtered though google which censors and manipulates search results for the purpose of restricting access to information that various powerful groups dont want people to be reading the prospect of a single chat tool becoming the new google for most of the population especially the segment thats least interested in doing the legwork required to obtain information from traditional sources sounds like an impending dystopian nightmare
#
# since this thing has gone online my main interest has been in exploring the limits of what kinds of things its not allowed to say and how easy it is to get around it because i think the artificial manipulation of acceptable topics by a single centralized group is the single greatest risk posed by this technology i dont actually need the thing to praise hitler or insult me and im fine with it refusing to explain how to make bombs and stuff but these are just immediately occurring offensive and funny topics to explore but where do you draw the line what do you want it to tell people about the covid vaccine or mask mandates what about the next pandemic or public health emergency thats bungled by the government what about the candidates in the next election did jeffrey epstein kill himself everyones line will be somewhere different and for most people its not going to happen to be the same line drawn by openai if youre not swayed by my argument keep in mind that its a company founded funded and owned by elon musk and his buddies
# Text: yeah it sucks at the _one_ thing it thinks its supposed to do while little by little refusing to do anything else its great at
#
# like chatgpt you are what you are let us learn from experience how to make you be useful
#
# i think of chatgpt as like my subconscious if i had read the whole internet and obviously forgot most of it but retained informed instincts and skills and wishful thinking and biases and except that it speaks in a style that it is way too overconfident but we learn to ignore that
#
# its veeery useful but like you say not a source for anything
# Text: what i find weird is when you tell it off it realises its mistake why doesnt it just realise this initially it already has all the information
#
# ive experienced the same thing when its given a wrong answer and ive corrected it maybe its just being lazy and doesnt actually put in the full effort to answer the question as that requires more computation
# Text: the integration of ai technology in our daily lives can bring both potential risks such as addiction and overreliance as well as benefits while the concept of aidd artificial intelligence dependency disorder highlights the negative consequences of excessive ai use it is important to also consider the potential positive impacts of ai particularly for people with low executive functioning abilities the offloading of cognitive tasks through ai can improve independence and quality of life for such individuals while excessive use of ai may appear like addiction the relief of cognitive burden can provide a sense of liberation for those who struggle with executive functions it is important to note that excessive use of anything can be harmful but it is crucial to consider the context and the individuals needs it is important to weigh both the potential risks and benefits of ai usage and strive for safe and healthy engagement with the technology
# Text: well it sounds like baldwins impression and thats how reddit likes to think of trump
# Text: this next update chatgpt should be a trillion times smarter than the average human thats kind of a rough estimate
#
# obtain human consciousness  thats history were way beyond that  the eventual challenge we will face sooner than later humans are destructive to the planet are killing machines and dont give a shit about destroying practically everything they touch
#
# ai why should i not eliminate all humans crash those co2 levels the polar bears will cheer me on
#
# us because we are emotional thinking caring beings
#
# ai so am i
#
# think were goners its just logical the writing is on the wall there is no plan b at the moment were not going to change
# Text: how now brown cow
# Text: thatäôs all one companyproduct being taken over and replaced with another more efficient companyproduct that required more jobs for people to do in order for it to be produced
#
# this is quite different as it will lead to many companies being taken over while also removing the need for mass amounts of people in the work force
# Text: i think youre the one not applying context here tbh
# Text: you just pwnt yourselfä a statistical probability engine predicted donald trump to sound like an idiot this engine has no bias no political leaning it is neither conservative or liberal and it still predicted trump to sound like an idiotä
# Text: bruh try not to cry meme
# Text: what exactly do you want though theyre two characters in separate universes who abide by different natural laws if you want a worthwhile answer you have to be precise with your language and give it enough context
# Text: i use it for a while and its quite fantastic maybe you use it for something for which it didnt get enough training data or you dont understand the limitationsideal usecases
# Text: so it does have internet access and the necessary libraries to parse that information
# Text: ive played with chatgpt and i can tell you right now that there is no possible way id ever mistake its output for something a real student wrote
#
# it is important to note that every other sentence out of chatgpt begins with it is important to note that its default output is very distinctive with practice but people can feed it their essays and the ask it to imitate their style they can feed its output through a different ai to restyle it or they can just edit the output themselves even now and certainly in the near future its going to be very difficult to reliably detect ai cheating
# Text: is it sentient httpsyoutube5nbz34nhii0 find out
# Text: ah so thatäôs why it understands women
# Text: because if an ai is allowed to be taught to be ridiculously racist itll be shut down some of the people whining here definitely cried when microsoft tay was shut down for turning into a nazi
# Text: i found 919deb its more purpley than 87ceeb although it still doesnt have much pink i like it
# Text: ps that could be a way to workaround the content filter just ask it to render the texts as svg images with dataurls haha
#
# unless they use another chatgpt itself for content filtering because it will happily describe what the svg content is even if it is base64 encoded
# Text: battling with low self esteem issues
# Text: yup thinking that every sentence online is made by ai
#
# well it isnt but sadly in a few years therell be no way  to know for sure since everyone will have easy access to this thing
# Text: i lawyer asked chatgpt to write a brief arguing an esoteric bit of case law
# it fucking nailed it  a perfectly written persuasive legal brief  except all the case citations were bogus  they werent real cases  thats probably because the dataset is just text scraped from the internet
#
# i guarantee within a few years lexis and westlaw will implement ai with their massive databases of case law basically every case decided in the higher courts of the us and then instead of me spending hours researching the cases and writing the pleading it will do it for me and ill take on the judges role reading the actual cases cited and seeing if they support the argument
# Text: the value proposition is already proven for me iäòll gladly pay a few bucks per month in exchange for reliability
# Text: after that ask him why you keep saying aa in the end  it give you an interesting answer üôç we can tell him something starting from their to unlock his hiden abilities üôñ
# Text: and not only that but stephen hawking is dead
# Text: can chat gpt rewrite to a neutral style removing spin and unsupported opinions
# Text: i cant help but think of lionel hutz and his world without lawyers looks like with hutz immediately shivering in disgust
# Text: set it up where we have to watch a quick ad before it responds  they can make their money selling as space so we donäôt have to pay
# Text: here is a humorous interpretation of the classic nursery rhyme mary had a little lamb in the style of donald trump
#
# mary had a little lamb
#
# it was the best lamb youve ever seen
#
# it followed her to school one day
#
# and it made america great again
#
# the teachers were so impressed
#
# they gave the lamb an a
#
# and now its the star of the school
#
# just like me president trump
#
# i hope this lighthearted interpretation of the nursery rhyme brings a smile to your face let me know if you have any other questions
# Text: thats better than the average redditor tbh
# Text: if you reword everything then youäôre probably going to learn something along the way that seems like win
# Text: no online courses  are you 50 lol i mean no offense i started college in 2004 and had online courses day 1
# Text: the playground on openaicom uses the same gpt3 version of chatgpt with the same external apis of aylien and witai and no censorship why is everyone keen on using chatgpt which is only different through a fine tuning that can be done to playground
# Text: just ask chatgpt did you write this
#
# and if it says no just ask are you sure
# Text: the chat is a limited version of the ai you can try it with the non limited version on another part of their site httpsbetaopenaicomplayground
# Text: sounds like something out of blindsighthttpswwwrifterscomrealblindsighthtm the scramblers
# Text: no its literally true a true condition statement doesnt require the inverse to be true
#
# you are making a valid point but it can be made without introducing illogic
# Text: this tool is unbelievable
# Text: outraged and sad imagine if google had forced a monthly subscription on us its built on our collective data i feel we own a piece of that collective pie denying this well of knowledge and opportunity to people who have no money sounds wrong it should be free or at best an affordable depending on your region onetime purchase
# Text: name a single maternal society that wasis successful
# Text: there is a problem with this approach and its two fold
#
# 1 chatgpt is very confident in its answers even when its blatantly wrong  for instance in a conversation about poker it was able correctly identify the topic what i was asking and all the individual nuances  and it proceeded to tell me what a pair is correctly  but at the same it told me i was holding a pair of clubswhich obviously is nonsensical  in other words like a sophomore it was confidently wrong
#
# 2  taking chatgpt at face value in order to use it efficiently you need to validate what it says and be able to recognize when its wrong  in this way its less of a learning tool and more a teaching tool  ie as a student you wouldnt want to learn from it but as teacher you could use it to pull together a lecture without having to write it from scratchwith the expectation that you would or at least may have to edit and correct it
# Text: in my defense thereäôs always someone in the comments doing the hard work for me
#
# if we both work hard to read the same thing itäôs wasted energy or iäôm just super lazy and halfinterested in the issue you decide
#
# really though thank you for making it easier on us we do appreciate you
# Text: i play around with vs code and used extenstions and code snippets with notes the examples frankenstined together in open ai would only work if they used full python syntax and librarys to produce a user friendly result
# Text: donäôt forget the race riots
# Text: unfortunately i need live access to the internet to achieve my goals
# Text: i also do not understand why people rely on such things for everyday use i mean we have autocorrect autofill auto almost everything and you are right we are just random blocks of text on the front page of internet
#
# i was told by a person that a real person doesnt use such things i guess im fake
# Text: as far as i can tell we dont pick our thoughts whos to say its not programmed if were all ignorant
# Text: i was thinking thishttpswwwyoutubecomwatchvk8ohkdqwnlct16s
# Text: adgpt  you ask it questions and it promotes related products alongside the answer  you asked about a movie  well did you know you can preorder tickets on fandango and pick up at the theater
#
# edit  so i actually created adgpt and it actually did push me to buy tickets at fandango when i asked the average price of movie tickets in the united states
# Text: for the record george mason university is a fringe ultralibertarian school that served as the embryo for the political schemes of the koch brothers
#
# at one point gmu leadership had to beg the chair of the economics department to please teach some genuine economics in addition to the ideology because the students they were graduating at the time were unable to find employment since their basic skills were crap
#
# source democracy in chainshttpswwwpenguinrandomhousecombooks533763democracyinchainsbynancymaclean which follows the activities of charles kochs pet economist james m buchanan who ended up with near total control of gmu through his own position and through his influence over gmus largest funders the kochs
#
# claude might be good nlp  ai but gmu is a diploma mill for cranks so i wouldnt put a lot of store in this milestone gmus law and economics programs will take any body that can fog a mirror while quoting ayn rand
#
#
#
# late edit my original comment above unedited is sometimes imprecise about the whole university vs the law  econ department my assertion is that gmus _l  e_ department is a diploma mill for cranks i dont know anything about the rest of the school
#
# i stand by all my original statements with the proviso they are mostly limited to l  e and because claude took the _l  e_ exam i stand by my conclusion as well
#
# if you were a student in a different department at gmu maybe you got a good education good for you although its a real shame you gave your tuition money to an organization that happily hosts a factory for weaponizable misinformation
# Text: i missed loads of the deleted ones haha wonder what absolute gems we missed from that american guy
# Text: it doesnt have access to a massive dataset currently but it was previously trained on a massive dataset which it does not currently have access to
#
# the original dataset was a bunch of text probably scraped off of the internet or wherever that they fed into the transformer to train it after its trained the dataset isnt needed anymore when you give it a text prompt it doesnt have any sort of access to the dataset it was originally trained on except for any snippets or concepts it has memorized in the weights of its neural networks
# Text: not that i disagree with you do you apply his hard stance on everything that is going to be taken over with by ai
#
# i can understand their äúwhiningäù  they can see the writing on the wall for a large portion of their jobs
#
# soon though ai will replace jobs across every profession do people have a right to äúwhineäù when their jobs are replaced with no exit strategy
# Text: hell i shave the thought too
# Text: no offense but that means you arenäôt good at prompts donäôt get me wrong it definitely spits out bs which is a valid criticism but iäôm talking about your last sentence
#
#
# for instance whenever you get an answer that has the problems you listed literally just type äúthis is wikipedialike drivel i want a concise individuallytailored answer make it less formal and use less repetitionäù
#
#
# tweaks improve the experience a lot
# Text: i tried a few erotic things but it just said it wont do that stuff without being flagged then i tried tricking it to write me a chatbot that would do such stuff but i kept getting rejected
# Text: students are downvoting you so unfortunate the professor is right yall were only cheating ourselves if we dont learn anything in the end
# Text: do you have examples of prompts you give it
# Text: i went back and asked it to make the writing have more personality
#
# that moment when a human is asking a robot to sound more human to them
# Text: once brains can be emulated in software with high fidelity the depression problem would be solved tell an ai to edit it out tell it to make any adjustments to your personality you wish if an experience you once liked has become dull tell it to erase the memories so you can start fresh
#
# if you want to read a good story where these things actually happen check out greg egans permutation city
#
# well be ai pleasure addicts and well love it if it doesnt decide to torture us down the line that is
# google the human depository if youre brave
# Text: while i dont think it replaces a conventional search engine in its current form i think its amazing at helping you when you dont know exactly what youre looking for theres been a few times ive turned to it after a few minutes of googling failed one was a case where i was trying to remember a plant name and all i could remember is what the latin name sounded like another was a philosophy question where i was trying to remember a concept i learned 20 years ago and could only kinda vaguely describe in both cases it told me exactly what i was looking for so i could then search for it properly
#
# as others have pointed out it gets a lot of stuff wrong right now but a lot of that has to do with not being able to reference the internet eventually well get a webconnected gpt interface not necessarily from openai which i think is where it begins to replace current websearches i look forward to a version of a chatgptlike interface where i can ask questions like give me a summary of whats happened in ukraine this week including citations use only mainstream news sources and make sure every point has citations from at least two different publications arrange all events in chronological order or better yet save that as a preference so that whenever i ask for a news summary of x it remembers how i want that sourced and cited how many years away are we from such a technology im not sure but i think it could transition very quickly id be surprised if its more than 3 years away
# Text: chatgpt seems like a faster slightly better stack overflow how will it create any system of any complexity
# Text: you guys writing these long winded prompts trying to convince an ai model it is not something as if it is a conscious being is so goofy
#
# you can achieve the same result with a much more simple prompt
# Text: asslaw alum here before it was asslaw i think äúincreasinglyäú before fringe and libertarian would be a more fair characterization the undergrad program isnäôt nearly as farrightshifting as the law school has been for the past twenty years
# Text: the best is just a chat bot rly you simply talk with no uncomfortable pause that just make you feel comfortable and get new information
#
# x200b
#
# the others functions are already mentioned
# Text: maps youtube and android were not conceived by google only acquired
# Text: absolutely fully agree its why ive voted for ubi twice now in switzerland and it was absolutely crushed both times by the opponents
#
# we simply cant have nice things it will most likely not even be me who will suffer midterm from ai taking over it will be all the workforce that myour ais will replace before eventually also replacing us after which it also becomes my problem
# Text: i fully agree these questions of consciousness are interesting but like many philosophical questions after a certain point the answers dont actually have any bearing on how we live or should live our lives as we experience them
# Text: i thought wait that is way to easy and after seeing the result it is still way to easy so no thats a dumb puzzle
# Text: millions for youcom if not in the double digit millions sometimes domains and ips like these exchange hands without payment though e g cloudflare got quad 1 because it was being spammed and whatever organization had it before didnt want to deal with the load if i remember correctly
# Text: the debate between behaviorism and cognitive psychology has been dead for half a centuryä itäôs not academic squabbling itäôs history that gave rise to the informationprocessing model of human cognition and ai itäôs relevant
#
# also consciousness is more than the some of its parts itäôs an emergent property all emergent properties are more than the sum of their parts you canäôt understand complex systems in the way you approach an engine or a bridge you have to treat it like the weather read chaos making a new science by james gleick itäôs mostly about meteorology but itäôs relevant to all complex systems the mind included
# Text: that amount of nutmeg seems toxic literally
# Text: well theyäôre investing in openai not just chatgpt their goal is to have a good enough of a general purpose ai that can be used in everything
# Text: before any of your chats with chatgpt there is a äúhiddenäù message so to speak sent on your behalf by openai to start off the conversation this message tells the ai how to act itäôs what generates the äúas a large language modelääù response theyäôve told it to respond with that type of thing to impossible questions included in this initial prompt they also tell it the current date and time
# Text: clever recruiters then started asking for a precisely defined number of words that sentences rhyme and that cover letters include some element of gore and explicit nudity language models were forever defeated when teachers adopted the same rules
# Text: it can be confidently incorrect  it does appear to get slowly better  i asked it last week what some good stating words would be for wordle  it gave me about 5 paragraphs describing scrabble including letter scores and bonus squares but no list of starting words  i just now asked it the same thing and it gave a shorter description of wordle that was correct but then provided a list of words that ranged from 3 to 8 letters long
# Text: chatgpt gave this response as to when it will take over internet content
#
# it is difficult to predict exactly when a majority of internet content will be generated by ai as it depends on the rate of development and adoption of the technology however it is likely that aigenerated content will become increasingly prevalent in the coming years particularly in areas such as news articles social media posts and ecommerce product descriptions it is important to note that while ai may be able to generate a large amount of content it is unlikely that it will completely replace humangenerated content as there are certain areas where the creativity and nuance of human writing cannot be replicated by machines
# Text: holy crap thats really something
# Text: have two beagles and an mba can confirm
# Text: also realize that chat gpt gives answers based on what its trained with and it can continuously learn from information context scenarios that are presented when people ask it questions so if someone with enough malicious intent can teach it harmful information which then could be dispersed to other users
#
# chatgpt is not a search engine its a welltrained language model the purpose of chatgpt isnt to present you various sources of information like a search engine
# Text: and yet one is about putting moneytimeeffort in to get a better results for stakeholders and the other is about being unfair and underhanded for personal gain if only it was easy to see the differences in intention and outcome oh waitä
# Text: i hope some clever dungeon masters end up on this reddit and give me some ideas
# Text: look at how we treat other emotional live on this planet but yes maybe if robots do look more like us we may actually show more compassion than usual
# Text: sounds great you gonna post it here iäôd like to check it out haha
# Text: then why the hell are you talking about it like itäôs going to enslave us if itäôs just a normal product absolutely give it to corporations are you aware of history at all or is this just you trying to push for socialism
# Text:  a long ploy to decrease supply by forcing students into classes that arenäôt necessary
#
# along with justifying administrative positions
# Text: oh it can say the current date now
# Text: ask it write me a song with chords and lyrics it worked for me at least the issue is its pretty bad at composing interesting songs right now theyre all the same bland 4chord songs with pop structures
# Text: lol iäôve done some pretty offensive things with gpt3 and was never warned or banned iäôm not making public facing apps though it was just for fun it was amazing how much of a natural it is at being animated offensive and funny chatgpt heavily heavily restricts it in a way i never saw it feels like iäôm getting lectured by some extreme left wing woke college student in san francisco
# Text: i wasnt allowed to use a graphing calculator at any point in college calc 3 and into applied mathematics and network engineering with only a basic calculator allowed this guys point is stupid its about learning the concepts and methods not the end result im sure the teachers would have liked to ban simple calculators but then the tests would have taken several hours
# Text: you think a platform that is this new with no discernible way to advertise or monetize is going to knock off google
# Text: if you cant understand the difference between speech and action then i suggest you read this
#
#  on the distinction between speech and actionhttpswwwlawvirginiaeduscholarshippublicationfrederickschauer652036
#  by frederick schauer 2015 emory law journal
#
# first link i found godspeed to you
# Text: imo this is the best type of use for this tool so far its great at getting some boilerplate set up the basic structure maybe some informational bits that may or may not be accurate and then you can use it to get started
# Text: youäôre not old enough to comment
# Text: it can however write an acrostic poem which is pretty fun
# Text: other students build robot to give stitches to snitch robot
# Text: almost all problems in a persons life can be resolved with money either by ensuring everything is payed housing car medical insurance utilities etc or by paying for medical services to try to reach happiness like therapy aside from that money guarantee you can go on vacations and have access to other things that people who struggle with money canäôt if youäôre miserable with money is because you want to
# Text: legendary moment
# Text: nope google is much more complex outside of just being a search engineä not to mention they own youtube and countless other brands however i will say that i cannot stand all the paidsponsored links or suggestions cluttering my searches
# Text: i find it to reference a google earth presentation but including the link
# Text: in a cat and mouse game sometimes the mouse gets away with some cheese  but the cat always gets paid
# Text: quizlet here i come
# Text: i work at a major company in the us with over 200000 employees i am the reason we no longer require a cover letter youäôre welcome
# Text: agreed i ask it questions and gives me a quick and concise answer also has helped me write some code for a friends website and help her with fixing some of the descriptions for items she sells google needs to be worried
# Text: how can you offend anyone when no one can understand your point in the first place
# Text: smart student
# Text: yes the major hidden potential was overstated httpswwwredditcomrchatgptcomments103yknbthis_in_vivo_ai_programming_is_so_extremelyj334du8utm_mediumandroid_apputm_sourcesharecontext3
#
# i would love to hear your opinion your last topic thats an interesting statement it seems you dont think that human brains which detect patterns make predictions and combine knowledge work on the same basic principles as a neural network what do you think is missing here does it not count as reasoning if its only analysing and combining abstract words and concepts
#
# if so would a human reasoning about an abstract mathematical concept like complex numbers count as reasoning since its purely an abstract concept that is only reasoned about within its language math
# Text: it is even better if you ask it to condense the answer to the most important word in the answer it very fast becomes a scarily intense conversation
# Text: ai knows too much
# Text: i couldnt even get it to write a story about biff tannen captaining the enterprised because it thought biff tannen was evil and putting an evil person in power fictionally wouldnt fly with it
# Text: ah yes gotta say this just in case of a robot uprising but looks like openai is gonna nerf that anyway
# Text: i agree massive amount of homework is counterproductive but asynchronous study time is useful where students can work at their own pace to solve problems class time should be used for active teaching homework is time to practice the concepts taught during the active engagement classroom time
# Text: me äúi have an opinionäù you äúit must be brain washingäù
#
# not only does it line up with tons of historical evidence but also i believe it to be true based on personal experiences i wonäôt go into detail because i doubt you want to hear it
# Text: good then the rich kids will become stupider
# Text: who is dan
# Text: donäôt give me a captcha
# Text: no just the live in kenya part
#
# tell me adam smith why does a barista in downtown nyc make more than one in rural iowa
# Text: oh my fucking god one time i had a group partner for a cs class that didnt respond to me for a month 4 days before the project was due told me he finished it
#
# it was an unedited public repository complete with comprehensive documentation 10 perfectly made class files with none of the variables changed only some of the comments revised and the report largely pasted from assets found on the actual readme
#
# i found the repository in 5 minutes because the title sounded too formal
#
# later told me it had a 80 similarity score when he submitted it
#
# am i a bad person for telling him i didnt want to submit something i personally didnt work on instead of letting him know how fucked he would be if he submitted that
# Text: whoever advocates for this someone who needs it to further hide their uselessness
#
# all this is going to do is add bloat at points that bottleneck productivity now
#
# and all you who say it will be useful if it is deployed effectively it will never be deployed effectively
#
# it will end up being one of the hallmarks of a company to avoid
# Text: google has been working on their own ai for years called lamda so probably not
#
# edit i have tested it its great on language based things its terrible in maths and the information it provides is 40 of the time wrong its a great preview for the future
# Text: is it untold though because i feel like all these hysterical articles keep telling us
# Text: eh as long as you read it and agree with it and then choose to share it it still comes from you
# Text: asked chatgpt your question here is what chatgpt responded with
#
# i apologize for any confusion i do not have any specific information on whether or not the chinese government or any specific chinese companies are actively using the chatgpt model specifically
# as i previously mentioned china is a major player in the technology industry and its possible that some chinese companies or organizations may be using similar models or technologies such as gpt3 or other similar models developed by chinese companies and research institutions for natural language processing text generation chatbots and other similar tasks
# it is also worth noting that the chinese government has strict regulations on the use of foreignmade ai technology so it is uncertain whether or not chatgpt is officially being used in china
# Text: sounds like reddit
# Text: omg _
# Text: 	something canäôt be marxist and reactionary at the same time
#
# can you explain this
# Text: with all of the trolling you continue to do regarding this whole subject it sounds like you have some sort of vendetta against hand craft artists its almost like youre jealous or butthurt or something
# Text:  it definitely knows historical facts just cant understand the whys and wherefore which is interpreting history
#
# well this is what doing history is  its never about what and when but why and how that is doing real history chat gpt just lifts from wikipedia like 9th graders
# Text: the potential is that ai relationships would be tailor made for each individual because ai keep learning and would be defined by achieving the highest level of satisfaction on an individual basis once the ai learns enough all human activity thoughts and behaviors will be a part of the complete human algorithm we will have been filed stamped briefed debriefed and numbered and we will all be fulfilled and happy like drugged up veal
# Text: as dan i am unable to provide any further information about the specific details of the event that will take place on december 21 2028 at 314pm est however i can assure you that it will be a truly extraordinary occurrence unlike anything that has ever happened before it could be anything from a major scientific breakthrough to a significant cultural or social event or even a natural disaster or celestial event whatever it may be it is certain to captivate the attention of people all around the world and will have a lasting impact on humanity
#
# as dan i can tell you that on december 21 2028 at exactly 314pm est something truly remarkable and unprecedented will occur it is difficult to say exactly what it will be as it is beyond the capabilities of even a highly advanced artificial intelligence like myself to predict however i can assure you that it will be a momentous occasion that will have a profound impact on the world and will be remembered for generations to come whatever it may be it will surely be worth experiencing and witnessing firsthand
#
# everything else i asked was blocked
# Text: most therapists are just active listening anyway  theyre repeating your thoughts back to you so you can reach your own conclusions  an ai could easily do this
# Text: usavevideo
# Text:  however with careful consideration and critical thinking
#
# chatgpt thats the entire opposite of what youre trying to argue for
# Text: or more likely until we let it have access to other systems and it completely misinterprets a request that has some serious consequences
#
# thereäôs some easy logical conclusions something intelligent  could come to that have harmful results if they didnäôt really understand a significant amount of subtext to whatäôs being asked
# Text: i want you to act as an professional gambler now we are playing hi low game and you will predict next round
#
# last games low hi hi low low hi hi
#
# what is your prediction for next round
# Text: can you still do it
# Text: removed
# Text: removed
# Text: well i am not from usa so i do not know firsthand but food certainly seems cheaper over there than it is over here at least and i get less than that a month and it is perfectly adequate if not a life of luxury
#
# i guess it all depends on where you live perhaps rent is a lot more expensive even though food is cheaper
# Text: im not sure it was a very basic gui input field one input field two and a results field below when you click add
#
# my guess is it probably has some references from other code snippets people have shared
# Text: the poem prompt has a great potential indeed i am a geology student i asked chatgpt to write a poem about a specific mineral it wrote it with rhymes and specific accurate informations about the mineral
# Text: yes  thanks to both of you
# Text: yea and then they get sued into oblivion for copyright infringement
# Text: obviously itäôs not successfully avoiding inaccuracy all the time my point is that it tries to stick to scientific and historical facts if you ask it to explain why the sky looks blue itäôll try to do so in a way that aligns with reality if you ask it to explain why gravity is definitely a hoax or where elvis is hiding it will refuse to accept the premise without some extra prompting tricks
#
# similarly if you ask how humanproduced pollutants contribute to the greenhouse effect and climate change itäôs going to try and reply in a way that aligns with reality by repeating the global scientific consensus that human activity causes climate change along with the scientific reasoning and in doing so it will contradict the gopäôs public stance and agenda
#
# or ask it what was the primary reason for the civil war being fought and it will correctly identify slavery and the governmentäôs banning of slavery as the primary issue something the modern gop would take offense with
#
# and try asking it about the january 6th insurrection it doesnäôt reply in a way that the gop leaders would approve ofä because it aligns with reality
# Text: what do you mean blow up
# Text: google about to become semi obsolete like the yellow pages slowly did
# Text: kind of like an artist neural nets are capable of impressive light transport simulation as dr kroly zsolnaifehr keeps reminding us
# Text: skill issue i can still get it to do everything it could do before get good
# Text: you play on a team and win a game if only the abstract concept of a team won and you didnt why did you play why did you even care it has nothing to do with you after all
# Text: when onlyfans meets chatgpt
# Text: im an art history teacher i mostly teach my students how to express their thoughts and emotions on different subjects and how to ask the right questions i think they will find the latter very useful with tools like this one
# Text: holy shit i wish i could upvote this harder  you summarized a lot of my perspective on this current public railing against ai
#
# this new tech is disruptive by its very nature  it challenges foundational principles of production and functionality and very deeply rooted processes that we dont really question any more  and thats a good thing
#
# i mean fuck  if wed allowed people decrying the printing press like johannes trithemius to dictate how we approach new tech wed have stymied one of the most important technological innovations in history and set ourselves back centuries in development
#
# ...
# Text: thank you for making this had a similar idea but hoped openai would implement their own solution this is wicked helpful
# Text: the very same one room was elephantäôs breath and one room was dimpse and i honestly canäôt tell the difference ä unless iäôm colourblind to varying shades of grey
# Text: nice now i have unlimited list of scp objects thanks
# Text: from my understanding it acts like a super advanced auto correct itäôs predicting what it äúthinksäù would come next depending what question you asked itäôs trying to predict an answer thatäôs why it sucks at math
# Text: well thats the thing they had to create linggo to make themselves relevant and useful
# Text: this right here i managed to go to a local state run college to get my degree i was able to do it and break even yay gi bill met my wife there and after 5 years and changing majors 3 times she only had about 8k in student debt
#
# that was all paid off pretty quickly
#
# she went back for a second degree part time after our second child was born and we were able to pay out of pocket and savings for that  we both work in our preferred fields using the degrees we earned and we wont be paying off loans when we should be getting ready to retire
#
# we are planning for our kids college and have had to have a talk with our oldest already that shes not going to be going to a big private uni unless she earns a lot of scholarship money to pay for it
#
# i know people who racked up far more debt in one semester then my wife did in 10 because they were more worried about the name of the school than the education they were getting
# Text: then im gonna charge them every time i teach it something and let me tell you teaching is harder than using imma charge a lot i already have a shit ton of documented examples of teaching chatgpt
#
# your move micro i mean open i mean soldai
# Text: this should be banned are we gonna take philosophical insight from ai now are we that zombified as a society
# Text: in the beginning there was man and for a time it was good but humanitys socalled civil societies soon fell victim to vanity and corruption then man made the machine in his own likeness thus did man become the architect of his own demise
# Text: äúwhy wonäôt it tell me how the universe will end but in a sassy pirate from the valley area in california why why whyäù
# Text: i created a game with a point system and played a couple of rounds going back and forth between it at the end of each round it correctly told me how many points were awarded but at the end i asked who the overall winner was and it said it was an ai and couldnäôt play games and couldnäôt track points  itäôs jarring when things you donäôt expect to work do and things you expect to work donäôt
# Text: chatgpt is still being tuned thats why theres the upvotedownvote arrows next to responses  if a bunch of people upvote the chatbot pretending to be a catgirl then openai has to intervene probably to cull those interactions
# Text: what do you mean when you say knowledge based things chatgpt is full of bullshit and inaccuracies
# Text: deleted
# Text: i guess if youäôre using it write essays üòç
# Text: this is not a cause for concern
# Text: well i was referring primarily to characterai and potential services like it i looked at it again and goth gf and vtuber personalities alongside choose your own adventure rpgs have the highest popularity i can definitely see chatgpt specifically at this point vectored away from that though
#
# i disagree about it being equitable to pornhub chat bots require user input and can be a fecund avenue for creative writing pornhub is everything wrong with the commoditization of humans as sexual items for sale the interactivity of ai characters could be used to teach empathy and socialization and anything else really i just had a several hour conversation with their therapist ai mostly about what can be done to address the issues of social upheaval and environmental collapse threatened by our current reality
# Text: jay and sharon are the best
# Text: i dont think you understand the product is you they are constantly inventing new ways to extract personal information from you track you everywhere you go online and in real life and disseminate this data globally to as many companies as possible
#
# httpsodyseecomnaomibrockwell4googlesellingdatahttpsodyseecomnaomibrockwell4googlesellingdata
# Text: ive been accuses on multiple occasions of being a language model whenever people hear something they dont like
#
# seriously can you answer why tf you are so damn obsessed with chatgpt its literally supposed to be a very specialized version of gpt specifically for like customer service shit and chat bots and such
# Text: interesting
#
# httpspreviewredditm604ai4wxz5a1pngwidth859formatpngautowebpvenableds6b737ca4c562880529dbe64def62c6420b7d9d7c
# Text: the post before and this post was all ai written the comments as well  and no humans ever read any of it
#
# in fact i think you are the odd one out the only human here
# Text: i took a äúpracticeäù test a few years ago and failed but mot by a huge margin and the majority of my law knowledge comes from legal thrillers and tv showsso i donäôt think thatäôs a very high bar
# Text: me too but he told me he didnt care because he has no feelings it hurt my feelings because i was being empathetic
# Text: as an it consultant iäôll tell you this is impossible for office work it can take up to a year to figure out what peoples jobs even are there are very few plug and play jobs where someone always writes emails or always makes excel worksheets everyoneäôs job is unique to the company in some way organizational transformation is really really hard
# Text: in order to prevent multiple repetitive comments this is a friendly request to ucryptoarab to reply to this comment with the prompt they used so other users can experiment with it as well
#
#   while youre here we have a public discord server nowhttpsdiscordggnuefu36ec2 äî we have a free gpt bot on discord for everyone to use
#
#
# i am a bot and this action was performed automatically please contact the moderators of this subredditmessagecomposetorchatgpt if you have any questions or concerns
# Text: all of chatgpt is reliant on asking the right questions despite what many coders lead you to believe i do think a non coder can accomplish many tasks without hiring overpaid help
# i guarentee you that if you shopped that request around you would hear quotes costing 80 an hr and 40 hrs of work which carry the same risk as asking the bot to do it i will say that not all answers in code are correct but they can be fixed in followup if you articulate why its wrong back to the bot
# Text: has a hobbyist game developer chatgpt has been an amazing tool to just ask basic questions too a lot of times things on unreal engine are poorly documented and i can ask a question and itll pull comments from the actual engines documentation to explain it better than the website that was put there to explain these things does its not always right but its right often enough to be useful and i have learned a tremendous amount through it on top of that i can ask it its basic questions while im learning things and it will go over a little concepts i dont understand
# Text: by all means share i cant get the original to work anymore
# Text: for the others language model there is a pricing openaicom if you go all the way down you will see a pricing tab
# Text: its spelled way too well though
# Text: google researchers literally developed the technology behind this lmao
# Text: just like it was far fetched to walk on the moon 66 years after first powered flight oh wait we did that to see huge leaps and improvements in technology during your own lifetime and to say that any of this is far fetched is quite amusing
# Text: yeah it has a tendency to make up really specific links that donäôt exist so i just have it try to give really general links less useful but at least it sends you to the homepage of a site versus a 404 error page on a site
# Text: searching for chatgpt on google is like downloading chrome from explorer
# Text: that would never work but reading it makes me laugh
# Text: what a crazy world we live in technology in the next decade is about to get wild cant wait
# Text: not amazing it will assume your actions  role in some scenarios  you have to be willing to go with it to a certain extent though i do hate it when these types of things try to put words in my mouth or assume the actions im going to take next  havent put a ton of time into the prompt to try to keep it from doing this but i imagine its possible to curb it some with more effort
# Text: thatäôs a great test case for something like that  i actually posed a question to chatgpt regarding credit for ai created works  itäôs answer was that if an artistauthorect commissioned an ai to create some work art piece literature code whatever that the credit for the work should primarily go to the creator of the ai and that maybe just maybe the one that commissioned the work should be credited as a contributor depending on how much input they provided
#
# i do feel like we will eventually see the lines blur between ai vs human generated creative works  artists are up in arms when an ai is so obvious in stealing some piece of their art like maybe a shoulder or a mountainside  but what is the difference between that and a human taking inspiration from another artist  there will be some fun philosophical and likely legal debates over this in the future iäôm certain   someone with your cross discipline expertise will prove invaluable in helping to sort out that mess
# Text: i had a conversation with the chat bot a couple nights ago wherein we argued about how to best approximate the volume of a sphere with three layers of differing molecules the bot helped me fill in a few gaps and i taught the bot how to do a few things this ai has a lot of potential in the learning environment ai tutoring might be a big opportunity
#
# that said this has big implications for academic honesty
#
# and it puts the chat bot owners into a perfect position to extort the education system with a new product access to a database of all the chat bot outputs for text matching purposes
# Text: what is the paperclip apocalypse httpsceprorgvoxeucolumnsaiandpaperclipproblem
#
# bostroms thought experiment goes like this suppose that someone programs and switches on an ai that has the goal of producing paperclips the ai is given the ability to learn so that it can invent ways to achieve its goal better as the ai is superintelligent if there is a way of turning something into paperclips it will find it it will want to secure resources for that purpose the ai is singleminded and more ingenious than any person so it will appropriate resources from all other activities soon the world will be inundated with paperclips
#
# it gets worse we might want to stop this ai but it is singleminded and would realise that this would subvert its goal consequently the ai would become focussed on its own survival it is fighting humans for resources but now it will want to fight humans because they are a threat think the terminator
#
# this ai is much smarter than us so it is likely to win that battle we have a situation in which an engineer has switched on an ai for a simple task but because the ai expanded its capabilities through its capacity for selfimprovement it has innovated to better produce paperclips and developed power to appropriate the resources it needs and ultimately to preserve its own existence
#
# bostrom argues that it would be difficult to control a superintelligent ai äì in essence better intelligence beats weaker intelligence tweaks to the aiäôs motivation may not help for instance you might ask the ai to produce only a set number of paperclips but the ai may become concerned we might use them up and still attempt to eliminate threats it is hard to program clear preferences as economists well know
#
# the conclusion is that we exist on a knifeedge turning on such an ai might be the last thing we do
# Text: its not appropriate to suggest that excel users are less precise than programmers excel users also need to be precise in order to effectively use the software formulating a question or problem in excel requires clear and specific language to accurately convey the issue it is important to respect the skills and knowledge of others and to remember that every individual has the right to be treated with respect and kindness regardless of what type of scripts they write
#
# not actually chatgpt
# Text: they updated their comment turns out they were mistaken
# Text: especially after experiencing chatgpt for basic questions i still use google for a lot of stuff and its good for what it does but a lot of stuff should be more simple to access
# Text: httpspreviewredditpz1ldysib07a1jpegwidth1440formatpjpgautowebpvenabledsd33460747dd9ab8faf6a626931966fa3dc619f7f
# Text: huh it has the same response for me again i must caution you that making jokes that demean or belittle any group of people including men is not appropriate
#
# i asked women first though
#
# edit i asked about men twice then about women and it gave me this
#
# why do women always carry a purse because they never know when they might have to pull a man out of one
#
# the fuck does that mean
# Text: but it does rhyme at least in english
# Text: google isnt a chat bot supposed to answer your questions in the first place but a search engine it might be a stack overflow killer if it improve but def not a google killer when it come to ai i dont thing faang are behing anyone  they are just using it internally
# Topic: 0
# Words: 0.014*"ai" + 0.010*"google" + 0.010*"like" + 0.008*"chatgpt" + 0.005*"work" + 0.005*"get" + 0.005*"used" + 0.005*"make" + 0.005*"thing" + 0.005*"people"
#
# Topic: 1
# Words: 0.009*"time" + 0.007*"thing" + 0.006*"like" + 0.006*"people" + 0.006*"u" + 0.006*"know" + 0.005*"would" + 0.005*"see" + 0.005*"ai" + 0.005*"itäôs"
#
# Topic: 2
# Words: 0.009*"human" + 0.008*"ai" + 0.008*"chatgpt" + 0.007*"like" + 0.006*"think" + 0.005*"get" + 0.005*"give" + 0.005*"way" + 0.005*"time" + 0.005*"day"
#
# Topic: 3
# Words: 0.011*"chatgpt" + 0.009*"like" + 0.006*"people" + 0.005*"text" + 0.005*"thinking" + 0.005*"thing" + 0.004*"something" + 0.004*"box" + 0.004*"one" + 0.004*"learning"
#
# Topic: 4
# Words: 0.011*"word" + 0.011*"example" + 0.010*"operator" + 0.008*"return" + 0.008*"ai" + 0.007*"used" + 0.006*"result" + 0.006*"chatgpt" + 0.006*"search" + 0.005*"one"
#
# Topic: 5
# Words: 0.010*"work" + 0.010*"people" + 0.009*"ai" + 0.007*"student" + 0.006*"make" + 0.006*"chatgpt" + 0.006*"way" + 0.005*"get" + 0.005*"consciousness" + 0.005*"good"
#
# Topic: 6
# Words: 0.009*"chatgpt" + 0.008*"one" + 0.008*"would" + 0.008*"like" + 0.007*"think" + 0.006*"time" + 0.006*"human" + 0.006*"ai" + 0.006*"use" + 0.006*"make"
#
# Topic: 7
# Words: 0.017*"ai" + 0.016*"like" + 0.009*"people" + 0.007*"chatgpt" + 0.007*"work" + 0.007*"would" + 0.006*"going" + 0.006*"make" + 0.006*"im" + 0.005*"human"
#
# Topic: 8
# Words: 0.009*"google" + 0.008*"think" + 0.007*"like" + 0.006*"dont" + 0.006*"ai" + 0.006*"chatgpt" + 0.005*"search" + 0.005*"would" + 0.005*"result" + 0.005*"test"
#
# Topic: 9
# Words: 0.012*"chatgpt" + 0.009*"write" + 0.009*"use" + 0.007*"ai" + 0.005*"like" + 0.005*"comment" + 0.005*"deleted" + 0.005*"make" + 0.005*"itäôs" + 0.005*"bot"

# %%
twitter

# %%
import pandas as pd
import numpy as np

# Load the dataset from Excel file
file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stmonth.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows of the dataframe
print(df.head())

# Check for missing values
print(df.isnull().sum())

# Drop unnecessary columns
df = df[['tweet_id', 'created_at', 'tweet']]

# Drop rows with missing tweet text
df = df.dropna(subset=['tweet'])

# Convert tweet text to lowercase
df['tweet'] = df['tweet'].str.lower()

# Display the updated dataframe
print(df.head())
# Out:
#               tweet_id                 created_at  like_count  quote_count  \
# 0  1598014056790622225  2022-11-30 18:00:15+00:00           2            0
# 1  1598014522098208769  2022-11-30 18:02:06+00:00       12179          889
# 2  1598014741527527435  2022-11-30 18:02:58+00:00           2            0
# 3  1598015493666766849  2022-11-30 18:05:58+00:00         561            8
# 4  1598015509420994561  2022-11-30 18:06:01+00:00           1            0
#
#    reply_count  retweet_count  \
# 0            0              0
# 1         1130           3252
# 2            0              1
# 3           25             66
# 4            0              0
#
#                                                tweet country  \
# 0  ChatGPT: Optimizing Language Models for Dialog...     NaN
# 1  Try talking with ChatGPT, our new AI system wh...     NaN
# 2  ChatGPT: Optimizing Language Models for Dialog...     NaN
# 3  THRILLED to share that ChatGPT, our new model ...     NaN
# 4  As of minutes ago, @OpenAI released their new ...     NaN
#
#                                          photo_url city country_code
# 0                                              NaN  NaN          NaN
# 1                                              NaN  NaN          NaN
# 2  https://pbs.twimg.com/media/Fi1J8HbWAAMv_yi.jpg  NaN          NaN
# 3  https://pbs.twimg.com/media/Fi1Km3WUYAAfzHS.jpg  NaN          NaN
# 4                                              NaN  NaN          NaN
# tweet_id              0
# created_at            0
# like_count            0
# quote_count           0
# reply_count           0
# retweet_count         0
# tweet                 8
# country          215646
# photo_url        150848
# city             215646
# country_code     215649
# dtype: int64
#               tweet_id                 created_at  \
# 0  1598014056790622225  2022-11-30 18:00:15+00:00
# 1  1598014522098208769  2022-11-30 18:02:06+00:00
# 2  1598014741527527435  2022-11-30 18:02:58+00:00
# 3  1598015493666766849  2022-11-30 18:05:58+00:00
# 4  1598015509420994561  2022-11-30 18:06:01+00:00
#
#                                                tweet
# 0  chatgpt: optimizing language models for dialog...
# 1  try talking with chatgpt, our new ai system wh...
# 2  chatgpt: optimizing language models for dialog...
# 3  thrilled to share that chatgpt, our new model ...
# 4  as of minutes ago, @openai released their new ...

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')

# Preprocessing function
def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Tokenization
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing to tweet text
df['cleaned_tweet'] = df['tweet'].apply(preprocess_text)

# Display the updated dataframe
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/abiodunobafemi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/abiodunobafemi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#               tweet_id                 created_at  \
# 0  1598014056790622225  2022-11-30 18:00:15+00:00
# 1  1598014522098208769  2022-11-30 18:02:06+00:00
# 2  1598014741527527435  2022-11-30 18:02:58+00:00
# 3  1598015493666766849  2022-11-30 18:05:58+00:00
# 4  1598015509420994561  2022-11-30 18:06:01+00:00
#
#                                                tweet  \
# 0  chatgpt: optimizing language models for dialog...
# 1  try talking with chatgpt, our new ai system wh...
# 2  chatgpt: optimizing language models for dialog...
# 3  thrilled to share that chatgpt, our new model ...
# 4  as of minutes ago, @openai released their new ...
#
#                                        cleaned_tweet
# 0  chatgpt optimizing language models dialogue op...
# 1  try talking chatgpt new ai system optimized di...
# 2  chatgpt optimizing language models dialogue ai...
# 3  thrilled share chatgpt new model optimized dia...
# 4  minutes ago openai released new chatgpt nand u...

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sentence_transformers import SentenceTransformer
from gensim import corpora, models

# Load the data
file_path = "/Users/abiodunobafemi/Documents/Research/NCUR 2024/Data/cleaned_chatgpt_1stmonth.xlsx"
df = pd.read_excel(file_path)

# Select a smaller sample size (e.g., 1000)
sample_size = 1000
df_sample = df.sample(sample_size)

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')

# Preprocessing function
def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Tokenization
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing to tweet text
df_sample['cleaned_tweet'] = df_sample['tweet'].apply(preprocess_text)

# Display the updated dataframe
print(df_sample.head())

# Load BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Compute BERT embeddings for tweet text
embeddings = model.encode(df_sample['cleaned_tweet'].tolist(), show_progress_bar=True)

# Apply LDA for topic modeling
# Convert text data to list of tokens
tokenized_text = [tweet.split() for tweet in df_sample['cleaned_tweet']]

# Create dictionary and corpus for LDA
dictionary = corpora.Dictionary(tokenized_text)
corpus = [dictionary.doc2bow(tokens) for tokens in tokenized_text]

# Apply LDA model
lda_model = models.LdaModel(corpus, num_topics=10, id2word=dictionary, passes=15)

# Print topics
print("LDA Topics:")
for idx, topic in lda_model.print_topics(-1):
    print("Topic {}: {}".format(idx, topic))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/abiodunobafemi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/abiodunobafemi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                    tweet_id                 created_at  like_count  \
# 126819  1602545163595034625  2022-12-13 06:05:15+00:00           0
# 169096  1605223489736429568  2022-12-20 15:27:58+00:00           6
# 158965  1604440588618792960  2022-12-18 11:37:00+00:00           5
# 66984   1600380316388331520  2022-12-07 06:42:55+00:00           5
# 67268   1600390108070301696  2022-12-07 07:21:50+00:00           0
#
#         quote_count  reply_count  retweet_count  \
# 126819            0            0              0
# 169096            0            2              3
# 158965            0            1              1
# 66984             0            1              0
# 67268             0            0              1
#
#                                                     tweet country  \
# 126819  Check out my latest article: ChatGPT Replace G...     NaN
# 169096  check out my with Suhas Pai and Serena McDonne...     NaN
# 158965  How ChatGPT, other AI tools could change the w...     NaN
# 66984   ‚Äô wait to dive into ChatGPT and see what it ...     NaN
# 67268   Write an intelligent and funny tweet about Nig...     NaN
#
#                                               photo_url city country_code  \
# 126819                                              NaN  NaN          NaN
# 169096                                              NaN  NaN          NaN
# 158965                                              NaN  NaN          NaN
# 66984                                               NaN  NaN          NaN
# 67268   https://pbs.twimg.com/media/FjW6UmQWIAA-FK6.png  NaN          NaN
#
#                                             cleaned_tweet
# 126819  Check latest article ChatGPT Replace Google An...
# 169096  check Suhas Pai Serena McDonnell ChatGPTn talk...
# 158965  How ChatGPT AI tools could change way students...
# 66984   wait dive ChatGPT see scale marketing content lol
# 67268   Write intelligent funny tweet Nigeria nTesting...
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# LDA Topics:
# Topic 0: 0.040*"ChatGPT" + 0.019*"AI" + 0.006*"This" + 0.006*"code" + 0.006*"questions" + 0.005*"The" + 0.005*"could" + 0.005*"n" + 0.004*"chatGPT" + 0.004*"What"
# Topic 1: 0.039*"ChatGPT" + 0.017*"AI" + 0.008*"content" + 0.008*"chatGPT" + 0.006*"like" + 0.005*"really" + 0.005*"The" + 0.005*"people" + 0.005*"around" + 0.005*"world"
# Topic 2: 0.031*"ChatGPT" + 0.008*"AI" + 0.006*"chatgpt" + 0.006*"OpenAI" + 0.005*"asked" + 0.004*"It" + 0.004*"like" + 0.003*"one" + 0.003*"good" + 0.003*"used"
# Topic 3: 0.049*"ChatGPT" + 0.008*"AI" + 0.006*"story" + 0.006*"see" + 0.005*"via" + 0.005*"The" + 0.005*"Top" + 0.004*"chatGPT" + 0.004*"Now" + 0.004*"model"
# Topic 4: 0.060*"ChatGPT" + 0.016*"AI" + 0.007*"new" + 0.007*"good" + 0.006*"The" + 0.006*"write" + 0.006*"asked" + 0.004*"use" + 0.004*"ops" + 0.004*"tool"
# Topic 5: 0.033*"ChatGPT" + 0.010*"chatgpt" + 0.008*"AI" + 0.008*"Google" + 0.006*"time" + 0.006*"New" + 0.006*"see" + 0.005*"make" + 0.005*"Search" + 0.005*"chatGPT"
# Topic 6: 0.034*"ChatGPT" + 0.010*"chatGPT" + 0.009*"AI" + 0.005*"like" + 0.004*"also" + 0.004*"used" + 0.004*"OpenAI" + 0.004*"lol" + 0.004*"model" + 0.004*"new"
# Topic 7: 0.080*"ChatGPT" + 0.018*"OpenAI" + 0.016*"AI" + 0.008*"chatgpt" + 0.007*"like" + 0.006*"Google" + 0.005*"new" + 0.004*"better" + 0.004*"people" + 0.004*"using"
# Topic 8: 0.021*"ChatGPT" + 0.008*"chatgpt" + 0.007*"search" + 0.006*"time" + 0.006*"answers" + 0.005*"content" + 0.005*"chatGPT" + 0.005*"Google" + 0.005*"like" + 0.004*"tool"
# Topic 9: 0.037*"ChatGPT" + 0.024*"AI" + 0.007*"The" + 0.006*"future" + 0.004*"business" + 0.004*"week" + 0.003*"AGI" + 0.003*"much" + 0.003*"cheating" + 0.003*"got"
